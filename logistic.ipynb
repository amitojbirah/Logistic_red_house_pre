# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("C:/Users/hp/udemy ml/Data Files/classi/House-Price.csv")

# %%
df
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 0     24.0       32.31     0.538     6.575  65.2   4.35   3.81   4.18   4.01
# 1     21.6       37.07     0.469     6.421  78.9   4.99   4.70   5.12   5.06
# 2     34.7       37.07     0.469     7.185  61.1   5.03   4.86   5.01   4.97
# 3     33.4       32.18     0.458     6.998  45.8   6.21   5.93   6.16   5.96
# 4     36.2       32.18     0.458     7.147  54.2   6.16   5.86   6.37   5.86
# ..     ...         ...       ...       ...   ...    ...    ...    ...    ...
# 501   22.4       41.93     0.573     6.593  69.1   2.64   2.45   2.76   2.06
# 502   20.6       41.93     0.573     6.120  76.7   2.44   2.11   2.46   2.14
# 503   23.9       41.93     0.573     6.976  91.0   2.34   2.06   2.29   1.98
# 504   22.0       41.93     0.573     6.794  89.3   2.54   2.31   2.40   2.31
# 505   19.0       41.93     0.573     6.030  80.8   2.72   2.24   2.64   2.42
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   resid_area   506 non-null    float64
#  2   air_qual     506 non-null    float64
#  3   room_num     506 non-null    float64
#  4   age          506 non-null    float64
#  5   dist1        506 non-null    float64
#  6   dist2        506 non-null    float64
#  7   dist3        506 non-null    float64
#  8   dist4        506 non-null    float64
#  9   teachers     506 non-null    float64
#  10  poor_prop    506 non-null    float64
#  11  airport      506 non-null    object
#  12  n_hos_beds   498 non-null    float64
#  13  n_hot_rooms  506 non-null    float64
#  14  waterbody    506 non-null    object
#  15  rainfall     506 non-null    int64
#  16  bus_ter      506 non-null    object
#  17  parks        506 non-null    float64
# ...

# %%
df.describe()
# Out:
#             price  resid_area    air_qual    room_num         age       dist1  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854   41.136779    0.554695    6.284634   68.574901    3.971996
# std      9.182176    6.860353    0.115878    0.702617   28.148861    2.108532
# min      5.000000   30.460000    0.385000    3.561000    2.900000    1.130000
# 25%     17.025000   35.190000    0.449000    5.885500   45.025000    2.270000
# 50%     21.200000   39.690000    0.538000    6.208500   77.500000    3.385000
# 75%     25.000000   48.100000    0.624000    6.623500   94.075000    5.367500
# max     50.000000   57.740000    0.871000    8.780000  100.000000   12.320000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  498.000000
# mean     3.628775    3.960672    3.618972   21.544466   12.653063    7.899767
# ...

# %%
sns.boxplot(y='n_hot_rooms', data=df)
# Out:
# <AxesSubplot:ylabel='n_hot_rooms'>

# %%
np.percentile(df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
uv=np.percentile(df.n_hot_rooms,[99])[0]

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 2     34.7       37.07    0.4690     7.185  61.1   5.03   4.86   5.01   4.97
# 166   50.0       49.58    0.6050     7.929  96.2   2.11   1.91   2.31   1.86
# 204   50.0       32.68    0.4161     8.034  31.9   5.41   4.80   5.28   4.99
# 267   50.0       33.97    0.5750     8.297  67.0   2.60   2.13   2.43   2.52
# 369   50.0       48.10    0.6310     6.683  96.8   1.55   1.28   1.65   0.94
# 423   13.4       48.10    0.6140     6.103  85.1   2.08   1.80   2.34   1.87
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 2        22.2       4.03      NO       7.394       101.12      None        38
# 166      25.3       3.70     YES       8.300        15.40     River        37
# 204      25.3       2.88     YES       8.900        15.40     River        51
# 267      27.0       7.44     YES       8.000        15.40      None        42
# ...

# %%
df.n_hot_rooms[(df.n_hot_rooms>3*uv)]=3*uv
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_2696/3972581706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.n_hot_rooms[(df.n_hot_rooms>3*uv)]=3*uv

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 2     34.7       37.07    0.4690     7.185  61.1   5.03   4.86   5.01   4.97
# 166   50.0       49.58    0.6050     7.929  96.2   2.11   1.91   2.31   1.86
# 204   50.0       32.68    0.4161     8.034  31.9   5.41   4.80   5.28   4.99
# 267   50.0       33.97    0.5750     8.297  67.0   2.60   2.13   2.43   2.52
# 369   50.0       48.10    0.6310     6.683  96.8   1.55   1.28   1.65   0.94
# 423   13.4       48.10    0.6140     6.103  85.1   2.08   1.80   2.34   1.87
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 2        22.2       4.03      NO       7.394     46.19856      None        38
# 166      25.3       3.70     YES       8.300     15.40000     River        37
# 204      25.3       2.88     YES       8.900     15.40000     River        51
# 267      27.0       7.44     YES       8.000     15.40000      None        42
# ...

# %%
df.n_hos_beds=df.n_hos_beds.fillna(df.n_hos_beds.mean(),inplace=True)

# %%
df['avg']=(df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
del df['dist1']
del df['dist2']
del df['dist4']
del df['dist3']

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#      price  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0     24.0       32.31     0.538     6.575  65.2      24.7       4.98
# 1     21.6       37.07     0.469     6.421  78.9      22.2       9.14
# 2     34.7       37.07     0.469     7.185  61.1      22.2       4.03
# 3     33.4       32.18     0.458     6.998  45.8      21.3       2.94
# 4     36.2       32.18     0.458     7.147  54.2      21.3       5.33
# ..     ...         ...       ...       ...   ...       ...        ...
# 501   22.4       41.93     0.573     6.593  69.1      19.0       9.67
# 502   20.6       41.93     0.573     6.120  76.7      19.0       9.08
# 503   23.9       41.93     0.573     6.976  91.0      19.0       5.64
# 504   22.0       41.93     0.573     6.794  89.3      19.0       6.48
# 505   19.0       41.93     0.573     6.030  80.8      19.0       7.88
#
#      n_hot_rooms  rainfall     parks  Sold     avg  airport_NO  airport_YES  \
# ...

# %%
# del df['airport_NO']
# del df['waterbody_Lake and River']
# del df['waterbody_None']

# %%
del df['waterbody_River']

# %%
df
# Out:
#      price  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0     24.0       32.31     0.538     6.575  65.2      24.7       4.98
# 1     21.6       37.07     0.469     6.421  78.9      22.2       9.14
# 2     34.7       37.07     0.469     7.185  61.1      22.2       4.03
# 3     33.4       32.18     0.458     6.998  45.8      21.3       2.94
# 4     36.2       32.18     0.458     7.147  54.2      21.3       5.33
# ..     ...         ...       ...       ...   ...       ...        ...
# 501   22.4       41.93     0.573     6.593  69.1      19.0       9.67
# 502   20.6       41.93     0.573     6.120  76.7      19.0       9.08
# 503   23.9       41.93     0.573     6.976  91.0      19.0       5.64
# 504   22.0       41.93     0.573     6.794  89.3      19.0       6.48
# 505   19.0       41.93     0.573     6.030  80.8      19.0       7.88
#
#      n_hot_rooms  rainfall     parks  Sold     avg  airport_NO  airport_YES  \
# ...

# %%
x=df[['price']]

# %%
y=df['Sold']

# %%
import sklearn

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(x,y)
# Out:
# LogisticRegression()

# %%
import statsmodels.api as sn

# %%
x_cons=sn.add_constant(x)
# Out:
# D:\conda\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
import statsmodels.discrete.discrete_model as sm

# %%
logit=sm.Logit(y,x_cons).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.676690
#          Iterations 5

# %%
logit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   Sold   No. Observations:                  506
# Model:                          Logit   Df Residuals:                      504
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 29 Apr 2022   Pseudo R-squ.:                 0.01788
# Time:                        18:33:39   Log-Likelihood:                -342.41
# converged:                       True   LL-Null:                       -348.64
# Covariance Type:            nonrobust   LLR p-value:                 0.0004142
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6149      0.248      2.484      0.013       0.130       1.100
# price         -0.0357      0.010     -3.417      0.001      -0.056      -0.015
# ...

# %% [markdown]
# # multiple predictor

# %%
X=df.loc[:,df.columns!='Sold']

# %%
y=df['Sold']

# %%
lr1=LogisticRegression()

# %%
lr1.fit(X,y)
# Out:
# D:\conda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr1.coef_
# Out:
# array([[-0.24482086, -0.00842397, -0.22235764,  0.93217798, -0.00569857,
#          0.24662531, -0.20620111, -0.08477719, -0.0057817 , -0.0117072 ,
#         -0.30853722,  0.05784625, -0.0196261 , -0.15798625, -0.11882458,
#         -0.20260736,  0.03822015]])

# %%
x_co=sn.add_constant(X)
# Out:
# D:\conda\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
lo=sm.Logit(y,x_co).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.562534
#          Iterations 6

# %%
lo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   Sold   No. Observations:                  506
# Model:                          Logit   Df Residuals:                      490
# Method:                           MLE   Df Model:                           15
# Date:                Fri, 29 Apr 2022   Pseudo R-squ.:                  0.1836
# Time:                        18:34:11   Log-Likelihood:                -284.64
# converged:                       True   LL-Null:                       -348.64
# Covariance Type:            nonrobust   LLR p-value:                 5.250e-20
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# price                       -0.2666      0.033     -8.195      0.000      -0.330      -0.203
# ...

# %%
y_pred=lr1.predict(X)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y,y_pred)
# Out:
# array([[202,  74],
#        [ 83, 147]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score, roc_auc_score

# %%
precision_score(y,y_pred)
# Out:
# 0.665158371040724

# %%
recall_score(y,y_pred)
# Out:
# 0.6391304347826087

# %%
roc_auc_score(y,y_pred)
# Out:
# 0.6855072463768116

# %% [markdown]
# # LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lr5=LinearDiscriminantAnalysis()

# %%
lr5.fit(X,y)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pd4=lr5.predict(X)

# %%
confusion_matrix(y,y_pd4)
# Out:
# array([[200,  76],
#        [ 77, 153]], dtype=int64)
